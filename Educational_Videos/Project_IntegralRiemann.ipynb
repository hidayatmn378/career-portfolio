# %%
from manim import *

class Scene1(Scene):
    def construct(self):
        text1=Text("Menghitung Integral Luas - Aplikasi Integral", font_size=40, weight=BOLD)
        text1.set_color_by_gradient(YELLOW, RED)
        text2=Text("Author: Muh. Nur Hidayat \n NPM: 2108201010005", font_size=40)
        text2[0:6].set_color(YELLOW)
        text2[0:6].set_color(YELLOW)
        text2[21:24].set_color(YELLOW)
        
        rectangle = SurroundingRectangle(text1, color=RED, buff=0.1)
        
        self.play(Create(rectangle))
        self.play(Write(text1),run_time=5.5)
        self.play(Unwrite(text1, reverse=True))
        self.play(Uncreate(rectangle))
        self.play(Write(text2),run_time=5.5)
        self.play(Unwrite(text2, reverse=False))
        self.wait()
                
# %manim -qm -v WARNING Scene1
# Out:
# Manim Community v0.16.0.post0
# <video src="media\jupyter\Scene1@2022-11-24@03-08-10.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene1(Scene):
    def construct(self):
        text1=Text("Menghitung Integral Luas - Aplikasi Integral", font_size=40, weight=BOLD)
        text1.set_color_by_gradient(YELLOW, RED)
        text2=Text("Author: Muh. Nur Hidayat \n NPM: 2108201010005", font_size=40)
        text2[0:6].set_color(YELLOW)
        text2[0:6].set_color(YELLOW)
        text2[21:24].set_color(YELLOW)
        
        rectangle = SurroundingRectangle(text1, color=RED, buff=0.1)
        
        self.add(text1,rectangle)
                
# %manim -qm -v WARNING Scene1

# %%
from manim import *

class Scene1(Scene):
    def construct(self):
        text1=Text("Menghitung Integral Luas - Aplikasi Integral", font_size=40, weight=BOLD)
        text1.set_color_by_gradient(YELLOW, RED)
        text2=Text("Author: Muh. Nur Hidayat \n NPM: 2108201010005", font_size=40)
        text2[0:6].set_color(YELLOW)
        text2[0:6].set_color(YELLOW)
        text2[21:24].set_color(YELLOW)
        
        rectangle = SurroundingRectangle(text1, color=RED, buff=0.1)
        
        self.add(text2)
                
# %manim -qm -v WARNING Scene1

# %%
from manim import *
class Scene2(Scene):
    def construct(self):
        paragraphe = Paragraph("1. Luas Di bawah Kurva - Persegi\n",
                              "2. Luas Di bawah Kurva - Trapesium\n",
                              "3. Integral Luas terhadap Sumbu-X\n",
                              "4. Integral Riemann\n",
                              "5. Contoh Soal - Pembahasan")
        paragraphe.scale(0.6)
        paragraphe.to_corner(UL) 
        
        underline1 = Underline(paragraphe[0:1], color=RED, buff=0.1)
        underline2 = Underline(paragraphe[1:4], color=RED, buff=0.1)
        underline3 = Underline(paragraphe[4:6], color=RED, buff=0.1)
        underline4 = Underline(paragraphe[6:8], color=RED, buff=0.1)
        underline5 = Underline(paragraphe[8:15], color=RED, buff=0.1)
        
        self.play(Write(paragraphe))
        self.play(GrowFromCenter(underline1), run_time=1.5)
        self.wait()
        self.play(GrowFromCenter(underline2), run_time=1.5)
        self.wait()
        self.play(GrowFromCenter(underline3), run_time=1.5)
        self.wait()
        self.play(GrowFromCenter(underline4), run_time=1.5)
        self.wait()
        self.play(GrowFromCenter(underline5), run_time=1.5)
        self.wait(3)
        
# %manim -qm -v WARNING Scene2
# Out:
# <video src="media\jupyter\Scene2@2022-11-24@03-08-18.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
class Scene2(Scene):
    def construct(self):
        paragraphe = Paragraph("1. Luas Di bawah Kurva - Persegi\n",
                              "2. Luas Di bawah Kurva - Trapesium\n",
                              "3. Integral Luas terhadap Sumbu-X\n",
                              "4. Integral Riemann\n",
                              "5. Contoh Soal - Pembahasan")
        paragraphe.scale(0.6)
        paragraphe.to_corner(UL) 
        
        underline1 = Underline(paragraphe[0:1], color=RED, buff=0.1)
        underline2 = Underline(paragraphe[1:4], color=RED, buff=0.1)
        underline3 = Underline(paragraphe[4:6], color=RED, buff=0.1)
        underline4 = Underline(paragraphe[6:8], color=RED, buff=0.1)
        underline5 = Underline(paragraphe[8:15], color=RED, buff=0.1)
        
        self.add(paragraphe,underline1,underline2,underline3,underline4,underline5)
        
# %manim -qm -v WARNING Scene2

# %%
from manim import *

class Scene3(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 6],
            x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
            y_axis_config={"numbers_to_include": [0, 5]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: 5, x_range=[0, 6], color=BLUE_C)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=GREEN_B,
        )
        
        t_label = ax.get_graph_label(
            graph=curve_1,
            label= MathTex(r"y=5"),
            x_val=6,
            dot=False,
            direction=UR)
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Hitung luas daerah yang diarsir?", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =MathTex(
            "L = p \\times l = 3 \\times 5 = 15 \\text{ satuan luas}"
        )
        self.add(ax, labels, transform_title)
        
        self.play(Create(curve_1),run_time=2)
        self.wait()
        self.add(t_label)
        self.play(Create(curve_2),run_time=2)
        self.wait()
        self.play(Create(line_1),run_time=0.5)
        self.wait()
        self.play(Create(line_2),run_time=0.5)
        self.wait()
        self.play(Create(area),run_time=2.5)
        self.wait(3)
        self.play(Create(hasil_title),run_time=5.5)
        self.wait(3)
        
        self.play(Uncreate(hasil_title))
        self.play(Uncreate(area))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, t_label, transform_title)             
        self.wait(2)
        
# %manim -qm -v WARNING Scene3
# Out:
# <video src="media\jupyter\Scene3@2022-11-24@03-08-24.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene3(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 6],
            x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
            y_axis_config={"numbers_to_include": [0, 5]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: 5, x_range=[0, 6], color=BLUE_C)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=GREEN_B,
        )
        
        t_label = ax.get_graph_label(
            graph=curve_1,
            label= MathTex(r"y=5"),
            x_val=6,
            dot=False,
            direction=UR)
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Hitung luas daerah yang diarsir?", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =MathTex(
            "L = p \\times l = 3 \\times 5 = 15 \\text{ satuan luas}"
        )
        self.add(ax, labels, curve_1,curve_2,t_label, line_1,line_2,area,transform_title)
        
        
# %manim -qm -v WARNING Scene3

# %%
from manim import *

class Scene3(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 6],
            x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
            y_axis_config={"numbers_to_include": [0, 5]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: 5, x_range=[0, 6], color=BLUE_C)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=GREEN_B,
        )
        
        t_label = ax.get_graph_label(
            graph=curve_1,
            label= MathTex(r"y=5"),
            x_val=6,
            dot=False,
            direction=UR)
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Hitung luas daerah yang diarsir?", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =MathTex(
            "L = p \\times l = 3 \\times 5 = 15 \\text{ satuan luas}"
        )
        self.add(ax, labels, curve_1,curve_2,t_label, line_1,line_2,area,transform_title,hasil_title)
        
        
# %manim -qm -v WARNING Scene3

# %%
from manim import *

class Scene4(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
            x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
            y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: 2*x, x_range=[0, 5], color=BLUE_C)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=GREEN_B,
        )
        
        t_label = ax.get_graph_label(
            graph=curve_1,
            label= MathTex(r"y=2x"),
            x_val=5,
            dot=False,
            direction=UR)
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=YELLOW, opacity=0.5)
    
        transform_title = Tex("Hitung luas daerah yang diarsir?", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =MathTex(
            "L = \\frac{1}{2}(a+b) \\times t = \\frac{1}{2}(4+10) \\times 3 = 21 \\text{ satuan luas}"
        )
        
        self.add(ax, labels, t_label, transform_title)
        
        self.play(Create(curve_1),run_time=2)
        self.wait()
        self.play(Create(curve_2),run_time=2)
        self.wait()
        self.play(Create(line_1),run_time=0.5)
        self.wait()
        self.play(Create(line_2),run_time=0.5)
        self.wait()
        self.play(Create(area),run_time=2.5)
        self.wait(3)
        self.play(Create(hasil_title),run_time=5.5)
        self.wait(3)
        
        self.play(Uncreate(hasil_title))
        self.play(Uncreate(area))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, t_label, transform_title)             
        self.wait(2)
# %manim -qm -v WARNING Scene4
# Out:
# <video src="media\jupyter\Scene4@2022-11-24@03-08-30.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene4(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
            x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
            y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: 2*x, x_range=[0, 5], color=BLUE_C)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=GREEN_B,
        )
        
        t_label = ax.get_graph_label(
            graph=curve_1,
            label= MathTex(r"y=2x"),
            x_val=5,
            dot=False,
            direction=UR)
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=YELLOW, opacity=0.5)
    
        transform_title = Tex("Hitung luas daerah yang diarsir?", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =MathTex(
            "L = \\frac{1}{2}(a+b) \\times t = \\frac{1}{2}(4+10) \\times 3 = 21 \\text{ satuan luas}"
        )
        
        self.add(ax, labels, curve_1,curve_2,t_label, line_1,line_2,area,transform_title,hasil_title)
 
# %manim -qm -v WARNING Scene4

# %%
from manim import *
class Scene5(Scene):
    def construct(self):
        text = Text("Nah, sekarang bagaimana dengan kurva yang bentuknya tidak beraturan?")
        text.scale(0.5)
        self.play(Create(text),run_time=2)
        self.wait(3)
        self.play(Uncreate(text,reverse=False))
        self.wait(3)
# %manim -qm -v WARNING Scene5
# Out:
# <video src="media\jupyter\Scene5@2022-11-24@03-08-32.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene6(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2,5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )
        
        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=BLUE, opacity=0.5)
    
        transform_title = Tex("Misalkan terdapat fungsi y=f(x)", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        hasil_title =Tex(
            "Bagaimana menghitung luas di bawah kurva ini?"
        )
        hasil_title.set_color(YELLOW)
        rectangle = BackgroundRectangle(hasil_title, color=RED, fill_opacity=0.5)
        
        self.add(ax, labels, x1_label, x2_label, transform_title)
        
        self.play(Create(curve_1),run_time=2)
        self.wait()
        self.play(Create(curve_2),run_time=2)
        self.wait()
        self.play(Create(line_1),run_time=0.5)
        self.wait()
        self.play(Create(line_2),run_time=0.5)
        self.wait()
        self.play(Create(area),run_time=2.5)
        self.wait(3)
        self.play(Create(hasil_title),run_time=2.5)
        self.play(Create(rectangle))
        self.wait(3)
        
        self.play(Uncreate(rectangle))
        self.play(Uncreate(hasil_title))
        self.play(Uncreate(area))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, x1_label, x2_label, transform_title)             
        self.wait(2)

# %manim -qm -v WARNING Scene6
# Out:
# <video src="media\jupyter\Scene6@2022-11-24@03-08-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene7(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )
        
        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

        riemann_area6 = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.5, color=BLUE, fill_opacity=0.5)
        riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.05, color=BLUE, fill_opacity=0.5)
#         area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Integral Riemann", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text1 = MathTex(r'\text{Luas tiap 1 persegi} \Rightarrow \;L&=p\;\times\; l \\ &=y\;\times\; \Delta x \\',
                        '&=\sum^{6}_{i=0}f_{L}(i)\Delta x', font_size=34)
        text1.to_corner(UP + LEFT - 0.8)
        
        text2 = MathTex(r'\text{Luas di bawah kurva} \Rightarrow &=\sum^{n\rightarrow \infty}_{i=0}f_{L}(i)\Delta x \\',
                        '&=\int^b_a f(x)dx',font_size=34)
        text2.to_corner(UP + LEFT - 0.8)

        self.add(ax, labels, x1_label, x2_label, transform_title)
        self.play(Create(curve_1))
        self.wait()
        self.play(Create(curve_2))
        self.wait()
        self.play(Create(line_1))
        self.wait()
        self.play(Create(line_2))
        self.wait()
        self.play(Create(riemann_area6),run_time=2)
        self.wait()
        self.play(Write(text1),run_time=5.5)
        self.wait(3)
        self.play(Uncreate(riemann_area6))
        self.play(Unwrite(text1))
        self.wait(3)
        self.play(Create(riemann_area),run_time=5.5)
        self.play(Write(text2),run_time=5.5)
        self.wait(3)
        
        self.play(Uncreate(riemann_area))
        self.play(Unwrite(text2))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, x1_label, x2_label, transform_title) 
        self.wait(1)
        
# %manim -qm -v WARNING Scene7
# Out:
# <video src="media\jupyter\Scene7@2022-11-24@03-08-52.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene7(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )
        
        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

        riemann_area6 = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.5, color=BLUE, fill_opacity=0.5)
        riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.05, color=BLUE, fill_opacity=0.5)
#         area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Integral Riemann", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text1 = MathTex(r'\text{Luas tiap 1 persegi} \Rightarrow \;L&=p\;\times\; l \\ &=y\;\times\; \Delta x \\',
                        '&=\sum^{6}_{i=0}f_{L}(i)\Delta x', font_size=34)
        text1.to_corner(UP + LEFT - 0.8)
        
        text2 = MathTex(r'\text{Luas di bawah kurva} \Rightarrow &=\sum^{n\rightarrow \infty}_{i=0}f_{L}(i)\Delta x \\',
                        '&=\int^b_a f(x)dx',font_size=34)
        text2.to_corner(UP + LEFT - 0.8)

        self.add(ax, labels, curve_1,curve_2,x1_label,x2_label, line_1,line_2,riemann_area6,transform_title, text1)
        
# %manim -qm -v WARNING Scene7

# %%
from manim import *

class Scene7(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )
        
        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

        riemann_area6 = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.5, color=BLUE, fill_opacity=0.5)
        riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.05, color=BLUE, fill_opacity=0.5)
#         area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Integral Riemann", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text1 = MathTex(r'\text{Luas tiap 1 persegi} \Rightarrow \;L&=p\;\times\; l \\ &=y\;\times\; \Delta x \\',
                        '&=\sum^{6}_{i=0}f_{L}(i)\Delta x', font_size=34)
        text1.to_corner(UP + LEFT - 0.8)
        
        text2 = MathTex(r'\text{Luas di bawah kurva} \Rightarrow &=\sum^{n\rightarrow \infty}_{i=0}f_{L}(i)\Delta x \\',
                        '&=\int^b_a f(x)dx',font_size=34)
        text2.to_corner(UP + LEFT - 0.8)

        self.add(ax, labels, curve_1,curve_2,x1_label,x2_label, line_1,line_2,riemann_area,transform_title, text2)
        
# %manim -qm -v WARNING Scene7

# %%
from manim import *

class Scene8(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )

        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)

        riemann_area6 = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.5, input_sample_type='right', color=BLUE, fill_opacity=0.5)
        riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.05,  input_sample_type='right', color=BLUE, fill_opacity=0.5)
#         area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Integral Riemann", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text1 = MathTex(r'\text{Luas tiap 1 persegi} \Rightarrow \;L&=p\;\times\; l \\ &=y\;\times\; \Delta x \\',
                        '&=\sum^{6}_{i=0}f_{R}(i)\Delta x', font_size=34)
        text1.to_corner(UP + LEFT - 0.8)
        
        text2 = MathTex(r'\text{Luas di bawah kurva} \Rightarrow &=\sum^{n\rightarrow \infty}_{i=0}f_{R}(i)\Delta x \\',
                        '&=\int^b_a f(x)dx',font_size=34)
        text2.to_corner(UP + LEFT - 0.8)

        self.add(ax, labels, x1_label, x2_label, transform_title)
        self.play(Create(curve_1))
        self.wait()
        self.play(Create(curve_2))
        self.wait()
        self.play(Create(line_1))
        self.wait()
        self.play(Create(line_2))
        self.wait()
        self.play(Create(riemann_area6),run_time=2)
        self.wait()
        self.play(Write(text1),run_time=5.5)
        self.wait(3)
        self.play(Uncreate(riemann_area6))
        self.play(Unwrite(text1))
        self.wait(3)
        self.play(Create(riemann_area),run_time=5.5)
        self.play(Write(text2),run_time=5.5)
        self.wait(3)
        
        self.play(Uncreate(riemann_area))
        self.play(Unwrite(text2))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, x1_label, x2_label, transform_title) 
        self.wait(1)
        
# %manim -qm -v WARNING Scene8
# Out:
# <video src="media\jupyter\Scene8@2022-11-24@03-09-10.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene9(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
#             x_axis_config={"numbers_to_include": [2, 5]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )

        line_1 = ax.get_vertical_line(ax.input_to_graph_point(2, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(5, curve_1), color=YELLOW)
        
        x1_label = ax.get_T_label(x_val=2, graph=curve_2, label=Tex("a"))
        x2_label = ax.get_T_label(x_val=5, graph=curve_2, label=Tex("b"))
        
        riemann_area6 = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.5, input_sample_type='center', color=BLUE, fill_opacity=0.5)
        riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[2, 5], dx=0.05,  input_sample_type='center', color=BLUE, fill_opacity=0.5)
#         area = ax.get_area(curve_2, [2, 5], bounded_graph=curve_1, color=GREY, opacity=0.5)
    
        transform_title = Tex("Integral Riemann", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text1 = MathTex(r'\text{Luas tiap 1 persegi} \Rightarrow \;L&=p\;\times\; l \\ &=y\;\times\; \Delta x \\',
                        '&=\sum^{6}_{i=0}f_{C}(i)\Delta x', font_size=34)
        text1.to_corner(UP + LEFT - 0.8)
        
        text2 = MathTex(r'\text{Luas di bawah kurva} \Rightarrow &=\sum^{n\rightarrow \infty}_{i=0}f_{C}(i)\Delta x \\',
                        '&=\int^b_a f(x)dx',font_size=34)
        text2.to_corner(UP + LEFT - 0.8)

        self.add(ax, labels, x1_label, x2_label, transform_title)
        self.play(Create(curve_1))
        self.wait()
        self.play(Create(curve_2))
        self.wait()
        self.play(Create(line_1))
        self.wait()
        self.play(Create(line_2))
        self.wait()
        self.play(Create(riemann_area6),run_time=2)
        self.wait()
        self.play(Write(text1),run_time=5.5)
        self.wait(3)
        self.play(Uncreate(riemann_area6))
        self.play(Unwrite(text1))
        self.wait(3)
        self.play(Create(riemann_area),run_time=5.5)
        self.play(Write(text2),run_time=5.5)
        self.wait(3)
        
        self.play(Uncreate(riemann_area))
        self.play(Unwrite(text2))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, x1_label, x2_label, transform_title) 
        self.wait(1)
        
# %manim -qm -v WARNING Scene9
# Out:
# <video src="media\jupyter\Scene9@2022-11-24@03-09-26.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene10(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
            x_axis_config={"numbers_to_include": [1, 4]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )

        line_1 = ax.get_vertical_line(ax.input_to_graph_point(1, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(4, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [1, 4], bounded_graph=curve_1, color=ORANGE, opacity=0.5)
    
        transform_title = Tex("Contoh Soal", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text2 = MathTex(r'L &=\int^b_a f(x)dx \\ &=\int^4_1 \frac{1}{3}x^2 dx \\&=\frac{1}{3 \times 3}(x^3)|^4_1 \\&=\frac{1}{9}((4)^3-1) \\&=7',font_size=34)
        text2.to_corner(UP )
        
        self.add(ax, labels, transform_title)
        self.play(Create(curve_1),run_time=2)
        self.wait()
        self.play(Create(curve_2),run_time=2)
        self.wait()
        self.play(Create(line_1),run_time=0.5)
        self.wait()
        self.play(Create(line_2),run_time=0.5)
        self.wait()
        self.play(Create(area),run_time=2.5)
        self.wait(3)
        self.play(Write(text2),run_time=5.5)
        self.wait(3)
        
        self.play(Unwrite(text2))
        self.play(Uncreate(area))
        self.play(Uncreate(line_1))
        self.play(Uncreate(line_2))
        self.play(Uncreate(curve_1))
        self.play(Uncreate(curve_2))
        self.remove(ax, labels, transform_title)             
        self.wait(2)

# %manim -qm -v WARNING Scene10
# Out:
# <video src="media\jupyter\Scene10@2022-11-24@03-09-32.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Scene10(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
            x_axis_config={"numbers_to_include": [1, 4]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )

        line_1 = ax.get_vertical_line(ax.input_to_graph_point(1, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(4, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [1, 4], bounded_graph=curve_1, color=ORANGE, opacity=0.5)
    
        transform_title = Tex("Contoh Soal", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text2 = MathTex(r'L &=\int^b_a f(x)dx \\ &=\int^4_1 \frac{1}{3}x^2 dx \\&=\frac{1}{3 \times 3}(x^3)|^4_1 \\&=\frac{1}{9}((4)^3-1) \\&=7',font_size=34)
        text2.to_corner(UP )
        
        self.add(ax, labels, curve_1,curve_2, line_1,line_2,area,transform_title)


# %manim -qm -v WARNING Scene10

# %%
from manim import *

class Scene10(Scene):
    def construct(self):
        ax = Axes(
            x_range=[0, 6],
            y_range=[0, 12],
            x_axis_config={"numbers_to_include": [1, 4]},
            tips=False,
#             y_axis_config={"numbers_to_include": [0, 10]},
        )

        labels = ax.get_axis_labels()

        curve_1 = ax.plot(lambda x: (1/3)*x**2, x_range=[0, 5.5], color=RED)
        curve_2 = ax.plot(
            lambda x: 0,
            x_range=[0, 6],
            color=BLUE_B,
        )

        line_1 = ax.get_vertical_line(ax.input_to_graph_point(1, curve_1), color=YELLOW)
        line_2 = ax.get_vertical_line(ax.i2gp(4, curve_1), color=YELLOW)

#         riemann_area = ax.get_riemann_rectangles(curve_1, x_range=[0.3, 0.6], dx=0.03, color=BLUE, fill_opacity=0.5)
        area = ax.get_area(curve_2, [1, 4], bounded_graph=curve_1, color=ORANGE, opacity=0.5)
    
        transform_title = Tex("Contoh Soal", font_size=72)
        transform_title.to_corner(UP + RIGHT)
        
        text2 = MathTex(r'L &=\int^b_a f(x)dx \\ &=\int^4_1 \frac{1}{3}x^2 dx \\&=\frac{1}{3 \times 3}(x^3)|^4_1 \\&=\frac{1}{9}((4)^3-1) \\&=7',font_size=34)
        text2.to_corner(UP )
        
        self.add(ax, labels, curve_1,curve_2, line_1,line_2,area,transform_title,text2)


# %manim -qm -v WARNING Scene10

# %%
from manim import *

class Scene11(Scene):
    def construct(self):
        text1 = Text(
            'Thanks',
            t2c={'[:1]': '#3174f0', '[1:2]': '#e53125',
                 '[2:3]': '#fbb003', '[3:4]': '#3174f0',
                 '[4:5]': '#269a43', '[5:]': '#e53125'}).scale(3)
        self.play(Write(text1),reverse=True,run_time=2)
        self.wait(2)
        
# %manim -qm -v WARNING Scene11
# Out:
# <video src="media\jupyter\Scene11@2022-11-24@03-09-32.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
